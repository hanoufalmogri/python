# %% [markdown]
# ## Name: Hanouf Almogri

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# 1. For the variable body_mass_g:
# Compute the proportion of penguins with body mass greater than the overall median body mass (among non-missing values).
# Compute the mean and variance of body_mass_g (same subset).

# %%
mass = df['body_mass_g'].dropna()

median_mass = mass.median()

proportion_greater_than_median = (mass > median_mass).mean()
mean_mass = mass.mean()
variance_mass = mass.var()

print("Median:", median_mass)
print("Proportion > median:", proportion_greater_than_median)
print("Mean:", mean_mass)
print("Variance:", variance_mass)
# Out:
# Median: 4050.0
# Proportion > median: 0.4853801169590643
# Mean: 4201.754385964912
# Variance: 643131.0773267479

# %% [markdown]
# 2. For body_mass_g, identify at least two distributional summary measures that describe center and spread (name them and compute them). Optionally add a third that describes shape (e.g. skewness), if you know how to compute it.

# %%
mass = df['body_mass_g'].dropna()

mean_mass = mass.mean()
median_mass = mass.median()
std_mass = mass.std()
variance_mass = mass.var()
iqr_mass = mass.quantile(0.75) - mass.quantile(0.25)
skewness_mass = mass.skew()

print("Mean:", mean_mass)
print("Median:", median_mass)
print("Standard deviation:", std_mass)
print("Variance:", variance_mass)
print("IQR:", iqr_mass)
print("Skewness:", skewness_mass)
# Out:
# Mean: 4201.754385964912
# Median: 4050.0
# Standard deviation: 801.9545356980955
# Variance: 643131.0773267479
# IQR: 1200.0
# Skewness: 0.4703293304801231

# %% [markdown]
# 1. In plain language, explain what the 75th percentile of body mass means for a penguin in this sample.

# %%
# The 75th percentile of body_mass_g means that 75% 
# of the penguins in the sample have a body mass less
# than or equal to that value, and 25% have a body 
# mass greater than it.

# %% [markdown]
# 2. Compute the 25th, 50th, and 75th percentiles for your chosen variable.

# %%
mass = df['body_mass_g'].dropna()

p25 = mass.quantile(0.25)
p50 = mass.quantile(0.50)
p75 = mass.quantile(0.75)

print("25th percentile:", p25)
print("50th percentile:", p50)
print("75th percentile:", p75)
# Out:
# 25th percentile: 3550.0
# 50th percentile: 4050.0
# 75th percentile: 4750.0

# %% [markdown]
# Assume for discussion that flipper length (or another chosen numeric column) were exactly normal with the mean and standard deviation you observe in the sample.

# %%
# For a normal distribution, the empirical rule says:
# About 68% of values fall within mean ± 1 standard deviation
# About 95% fall within mean ± 2 standard deviations
# About 99.7% fall within mean ± 3 standard deviations (its the basis for outlier detection and we always uess it in QA and Labs)

# %% [markdown]
# 3. For a normal distribution, explain what share of values fall within 1, 2, and 3 standard deviations of the mean (the empirical rule). Then compute the interval
# μ
# ±
# 1
# σ
# μ±1σ,
# μ
# ±
# 2
# σ
# μ±2σ, and
# μ
# ±
# 3
# σ
# μ±3σ using your sample
# μ
# μ and
# σ
# σ for that variable.

# %%
x = df['flipper_length_mm'].dropna()

mu = x.mean()
sigma = x.std()

interval_1 = (mu - sigma, mu + sigma)
interval_2 = (mu - 2*sigma, mu + 2*sigma)
interval_3 = (mu - 3*sigma, mu + 3*sigma)

print(f"mu ± 1σ: ({mu - sigma:.2f}, {mu + sigma:.2f})")
print(f"mu ± 2σ: ({mu - 2*sigma:.2f}, {mu + 2*sigma:.2f})")
print(f"mu ± 3σ: ({mu - 3*sigma:.2f}, {mu + 3*sigma:.2f})")
# Out:
# mu ± 1σ: (186.85, 214.98)
# mu ± 2σ: (172.79, 229.04)
# mu ± 3σ: (158.73, 243.10)

# %% [markdown]
# 1. Name two methods for identifying or removing outliers on a numeric column. For each, give a one-sentence explanation of the rule. Then show one method applied in code to flag outliers in bill_length_mm (do not delete them from the full dataset the count or indices is enough).

# %%
x = df['bill_length_mm']

Q1 = x.quantile(0.25)
Q3 = x.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = x[(x < lower_bound) | (x > upper_bound)]

print("Number of outliers:", outliers.count())
print("Outlier indices:")
print(outliers.index.tolist())
# Out:
# Number of outliers: 0
# Outlier indices:
# []
