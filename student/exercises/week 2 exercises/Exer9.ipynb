# %% [markdown]
# # Name: Hanouf Almogri

# %% [markdown]
# ### 1. Antibiotic use in children
# The bar plot and the pie chart below show the distribution of pre-existing medical conditions of children involved in a study on the optimal duration of antibiotic use in treatment of tracheitis, which is an upper respiratory infection.
#
# ![Alt Text](/Users/alhanoufalmogri/python-book/python/book/viz_exercise_1.png)
#
#
# 1. What features are apparent in the bar plot but not in the pie chart?
#
# 2. What features are apparent in the pie chart but not in the bar plot?
#
# 3. Which graph would you prefer to use for displaying these categorical data?

# %% [markdown]
# 1: In the bar plot, it’s easier to see exact comparisons between categories, the ranking from largest to smallest, and small differences in frequency.
#
# 2: In the pie chart, it’s easier to see that the categories are parts of one whole and to get a quick sense of each category’s proportion of the total.
#
# 3:I would usually prefer the bar plot for categorical data, because it is clearer and makes comparisons more accurate.
