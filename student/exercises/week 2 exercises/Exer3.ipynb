# %% [markdown]
# # Name: Hanouf Almogri
# ## Ex2 - Getting and Knowing your Data
# This time we are going to pull data directly from the internet. Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address.
#
#
# Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# Step 4. How many products cost more than $10.00?

# %%
(chipo["item_price"] > 10).sum()
# there are 1130 items that cost more than $10.00
# Out:
# np.int64(1130)

# %% [markdown]
# Step 5. What is the price of each item?

# %%
chipo[["item_name", 'quantity' ,"choice_description", "item_price"]]
# Out:
#                                   item_name  quantity  \
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 4                              Chicken Bowl         2
# ...                                     ...       ...
# 4617                          Steak Burrito         1
# 4618                          Steak Burrito         1
# 4619                     Chicken Salad Bowl         1
# 4620                     Chicken Salad Bowl         1
# 4621                     Chicken Salad Bowl         1
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# ...

# %% [markdown]
# Step 6. Sort by the name of the item

# %%
chipo[["item_name", 'quantity' ,"choice_description", "item_price"]].sort_values("item_name")
# Out:
#               item_name  quantity  \
# 3389  6 Pack Soft Drink         2
# 341   6 Pack Soft Drink         1
# 1849  6 Pack Soft Drink         1
# 1860  6 Pack Soft Drink         1
# 2713  6 Pack Soft Drink         1
# ...                 ...       ...
# 2384  Veggie Soft Tacos         1
# 781   Veggie Soft Tacos         1
# 2851  Veggie Soft Tacos         1
# 1699  Veggie Soft Tacos         1
# 1395  Veggie Soft Tacos         1
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...                                                 ...         ...
# 2384  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# ...

# %% [markdown]
# Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.loc[chipo["item_price"].idxmax(), "quantity"]
# Out:
# np.int64(15)

# %% [markdown]
# Step 8. What was the quantity of the most expensive item ordered?

# %%
chipo.loc[chipo["item_name"] == "Veggie Salad Bowl", "quantity"].sum()
# Out:
# np.int64(18)

# %% [markdown]
# Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo["item_name"] == "Canned Soda") & (chipo["quantity"] > 1)].shape[0]
# Out:
# 20
